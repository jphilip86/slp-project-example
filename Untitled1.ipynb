# %% [markdown]
# <a href="https://colab.research.google.com/github/jphilip86/slp-project-example/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("slpdata_numerical.csv")

# %%
df_clean = df.drop([0,1])

# %% [markdown]
# df.shape

# %%
df.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
#        'ExternalReference', 'LocationLatitude', 'LocationLongitude',
#        'DistributionChannel', 'UserLanguage', 'Q1', 'Q2', 'Q4', 'Q5', 'Q6',
#        'Q7', 'Q8', 'Q9', 'Q10', 'Q11', 'Q12', 'Q13_1', 'Q13_2', 'Q13_3',
#        'Q13_4', 'Q14', 'Q15', 'Q16', 'Q17', 'Q18', 'Q19'],
#       dtype='object')

# %%
df_simple=df_clean[['ResponseId','Q1', 'Q2', 'Q4', 'Q5', 'Q6',
       'Q7', 'Q8', 'Q9', 'Q10', 'Q11', 'Q12', 'Q13_1', 'Q13_2', 'Q13_3',
       'Q13_4']]

# %%
df_simple=df_simple.set_index('ResponseId')
df_simple
# Out:
#                   Q1 Q2 Q4 Q5 Q6 Q7 Q8 Q9 Q10 Q11 Q12 Q13_1 Q13_2 Q13_3 Q13_4
# ResponseId
# R_6fn5ekDobUP1m5g  4  3  1  2  2  3  3  3   2   2   4     1     4     5     3
# R_3KR0mBnSZdjoJAa  1  1  5  3  2  1  3  3   1   2   4     3     2     1     1
# R_5gqVnk14OjcBmXI  4  3  4  4  2  3  3  3   2   1   4     4     3     3     4
# R_0HUEeMmeNFs5WZw  3  3  2  2  4  1  1  1   3   4   5     1     2     5     4
# R_7TYgOzdHL53Y5Ho  1  3  1  3  2  1  4  1   2   3   4     3     4     3     5
# ...               .. .. .. .. .. .. .. ..  ..  ..  ..   ...   ...   ...   ...
# R_8x0fqyHU55k51Eq  4  1  2  3  1  2  5  3   3   2   5     3     3     1     1
# R_72OeMk6x3Bgz7AG  2  3  4  5  2  2  1  1   2   4   2     4     3     1     2
# R_2rzg4pqMXolgfbg  1  1  4  2  1  1  5  1   3   3   2     3     2     3     2
# R_6G9pvj6waxWi4RM  3  2  5  1  5  3  3  1   1   2   2     5     2     4     4
# R_9GEi9QDgBzaApEi  1  2  1  5  1  1  1  1   2   3   2     3     2     4     5
#
# ...

# %%
df_simple=df_simple.astype(int)

# %%
df_simple.describe()
# Out:
#                 Q1           Q2           Q4           Q5           Q6  \
# count  1100.000000  1100.000000  1100.000000  1100.000000  1100.000000
# mean      3.053636     2.027273     2.943636     3.022727     2.916364
# std       1.426333     0.820119     1.413733     1.459315     1.407863
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.000000     1.000000     2.000000     2.000000     2.000000
# 50%       3.000000     2.000000     3.000000     3.000000     3.000000
# 75%       4.000000     3.000000     4.000000     4.000000     4.000000
# max       5.000000     3.000000     5.000000     5.000000     5.000000
#
#                 Q7           Q8           Q9          Q10          Q11  \
# count  1100.000000  1100.000000  1100.000000  1100.000000  1100.000000
# mean      2.003636     2.976364     2.008182     1.970000     3.029091
# std       0.804890     1.419155     0.816641     0.794665     1.390553
# ...

# %%
# this is a comment
